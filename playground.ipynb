# %%
import argparse
import os
import numpy as np
from oikit.oi_shape import OakInkShape
from oikit.oi_shape.utils import viz_dataset
from termcolor import cprint

import os
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
os.environ["OAKINK_DIR"] = "/home/yjtao_t/OakInk/oakink_data"
oi_shape = OakInkShape(category="mug")
# Out:
# ...
# 100%|██████████████████████████████████████████████| 28759/28759 [00:00<00:00, 1072632.75it/s]
# 28759it [00:14, 1994.11it/s]
# 100%|███████████████████████████████████████████████████████| 167/167 [00:02<00:00, 73.33it/s]

# %%
oi_shape

# %%
oi_shape[0]["verts"]
# Out:
# array([[ 0.02978633,  0.08272995,  0.01803378],
#        [ 0.04098696,  0.08394245,  0.01383131],
#        [ 0.03746659,  0.07680547,  0.02057972],
#        ...,
#        [ 0.01281918,  0.08169177, -0.02291812],
#        [ 0.00434759,  0.07896659, -0.02084085],
#        [ 0.02912445,  0.08703594, -0.01661309]], dtype=float32)

# %%
oi_shape[0]

# %%
# %matplotlib widget

fig = plt.figure(figsize=(10,10))
# ax = fig.add_subplot(111, projection='3d')
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim(-0.2,0.2)
ax.set_ylim(-0.2,0.2)
ax.set_zlim(-0.2,0.2)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.scatter(oi_shape[0]["obj_verts"][:,0], oi_shape[0]["obj_verts"][:,1], oi_shape[0]["obj_verts"][:,2],marker='.', s=4, label='Category')
ax.scatter(oi_shape[0]["joints"][:,0], oi_shape[0]["joints"][:,1], oi_shape[0]["joints"][:,2],marker='.', s=4, label='Category')


    
ax.set_title('Predicted Result')
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
